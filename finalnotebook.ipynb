# %% [markdown]
# Big Ideas Final Project
#
# What neighborhood has the most outdoor activities?
#
# Datasets used:
# https://data.wprdc.org/dataset/parks
# https://data.wprdc.org/dataset/playgrounds
# https://data.wprdc.org/dataset/playing-fields

# %%
import pandas as pd
import numpy as np

# %%
park_data= pd.read_csv("park.csv", index_col="id")
park_data.head(2)
# Out:
#                                name  type maintenance_responsibility  \
# id
# 2111959181           Able Long Park  Park           Parks - Southern
# 1109513049  Albert Turk Graham Park  Park           Parks - Schenley
#
#                                                         image  \
# id
# 2111959181  https://tools.wprdc.org/images/pittsburgh/park...
# 1109513049  https://tools.wprdc.org/images/pittsburgh/park...
#
#                 neighborhood  council_district  ward        tract  \
# id
# 2111959181         Beechview                 4    19  42003192000
# 1109513049  Crawford-Roberts                 6     3  42003030500
#
#             public_works_division  pli_division  police_zone fire_zone  \
# id
# 2111959181                      5            19            6      4-28
# 1109513049                      3             3            2       2-1
#
#              latitude  longitude
# id
# 2111959181  40.408118 -80.028197
# 1109513049  40.440507 -79.984018

# %%
playground_data= pd.read_csv("playground.csv", index_col="id")
playground_data.head(2)
# Out:
#                                 name  type maintenance_responsibility  \
# id
# 731501774       Able Long Playground   NaN            Parks - Western
# 1461276747  Albert Graham Playground   NaN           Parks - Schenley
#
#                                park       street  \
# id
# 731501774            Able Long Park    COAST AVE
# 1461276747  Albert Turk Graham Park  FORESIDE PL
#
#                                                         image  \
# id
# 731501774   https://tools.wprdc.org/images/pittsburgh/play...
# 1461276747  https://tools.wprdc.org/images/pittsburgh/play...
#
#                 neighborhood  council_district  ward        tract  \
# id
# 731501774          Beechview                 4    19  42003192000
# 1461276747  Crawford-Roberts                 6     3  42003030500
#
#             public_works_division  pli_division  police_zone fire_zone  \
# id
# 731501774                       5            19            6      4-28
# ...

# %%
playfield_data= pd.read_csv("playfield.csv", index_col="id")
playfield_data.head(2)
# Out:
#                          name has_lights            park  \
# id
# 1914615260  Arlington Field 1          t  Arlington Park
# 1151740179          Armstrong          f  Armstrong Park
#
#                         field_usage  goal_post infield_type  \
# id
# 1914615260             Diamond Only          0      Skinned
# 1151740179  Diamond and Rectangular          0      Skinned
#
#             left_field_distance  center_field_distance  right_field_distance  \
# id
# 1914615260                160.0                  230.0                 290.0
# 1151740179                240.0                  163.0                 122.0
#
#             backstop       neighborhood  council_district  ward        tract  \
# id
# 1914615260       NaN  South Side Slopes                 3    16  42003160800
# 1151740179       NaN   South Side Flats                 3    17  42003170200
#
#             public_works_division  pli_division  police_zone fire_zone  \
# id
# ...
